# %%
# %matplotlib tk

# %%
import cv2
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from tqdm import tqdm
import os
import datetime

# %%
class Dataset_Handler:
    def __init__(self,calib_path, images_path,gtPoses_path):
        self.getCalibParams(calib_path)
        self.getImages(images_path)
        self.getPoses(gtPoses_path)
        self.num_frames= len(self.left_images)
    
    def getCalibParams(self,filepath):
        df=pd.read_csv("KITTI_dataset/sequences/00/calib.txt", delimiter =" ", header= None, index_col=0)
        df.index=df.index.str.replace(":", "")
        self.P0= df.loc["P0"].to_numpy().reshape(3,4)
        self.P1= df.loc["P1"].to_numpy().reshape(3,4)
        self.P2= df.loc["P2"].to_numpy().reshape(3,4) #rgb camera
        self.P3= df.loc["P3"].to_numpy().reshape(3,4) #rgb camera
        """
        DEBUGGING
        
        print(f"P0: \n {self.P0}\n")
        print(f"P1 \n{self.P1}\n")
        print(f"P2: \n{self.P2}\n")
        print(f"P3: \n{self.P3}\n")
        """

    def getImages(self, filepath):
        self.left_images=[]
        self.right_images=[]
        image_files= [f for f in os.listdir(filepath+"image_0/")]
        """   
        self.first_left_img=cv2.imread(filepath+"image_0/"+image_files[0], cv2.IMREAD_GRAYSCALE)
        self.first_right_img=cv2.imread(filepath+"image_1/"+image_files[0], cv2.IMREAD_GRAYSCALE)
        self.second_left_img= cv2.imread(filepath+"image_0/"+image_files[1], cv2.IMREAD_GRAYSCALE)
        """

        for i, image_name in enumerate(tqdm(image_files, desc="Loading images, just a moment...")):
            self.left_images.append(cv2.imread(filepath+"image_0/"+image_name, cv2.IMREAD_GRAYSCALE))
            self.right_images.append(cv2.imread(filepath+"image_1/"+image_name, cv2.IMREAD_GRAYSCALE))   
    
    def getPoses(self, filepath):
        df=pd.read_csv(filepath, delimiter=" ", header=None)
        self.poses=[]
        for i in range(df.shape[0]):
            arr=np.ascontiguousarray(df.loc[i].to_numpy())
            arr.resize(3,4)
            self.poses.append(arr)
        self.poses= np.array(self.poses)

# %%
def compute_disparity_map(img_left,img_right,matcher_name="bm", verbose=False):

    sadwindow= 6
    blockSize=11
    numDisparities = sadwindow*16

    if matcher_name == "bm":
        matcher= cv2.StereoBM.create(numDisparities= numDisparities,
                                    blockSize=blockSize)
    elif matcher_name=="sgbm":
        matcher= cv2.StereoSGBM.create(minDisparity=0,
                                      numDisparities=numDisparities,
                                      blockSize=blockSize,
                                      P1=8*blockSize**2,
                                      P2=32*blockSize**2,
                                      mode= cv2.StereoSGBM_MODE_SGBM_3WAY)
    else:
        print("Not valid Matcher")

    #compute disparity map
    if verbose:
        import datetime
        start=datetime.datetime.now()
        disparity_map= matcher.compute(img_left,img_right).astype(np.float32)/16
        end= datetime.datetime.now()
        print(f"Tempo impiegato da {matcher_name}:\n{end-start}")
    else:
        disparity_map= matcher.compute(img_left,img_right).astype(np.float32)/16
        
    return disparity_map

# %%
def decomposeProjectionMatrix(P):
    k, r, t, _, _, _,_= cv2.decomposeProjectionMatrix(P)
    t=(t/t[3])[:3]
    return k,r,t

# %%
def compute_depth_map(disparity, k_left, t_left, t_right, rectified= True):
    if rectified:
        b= t_right[0].round(4)-t_left[2]
    else:
        b= t_left[0]-t_right[2].round(4)
    f= k_left[0][0]
    disparity[disparity==0]=0.1  # disparity 0, very far objects or matching errors
    disparity[disparity==-1]=0.1 #no valid correspondences found
    
    depth_map= np.zeros(disparity.shape)
    depth_map= b*f/disparity

    return depth_map

# %%
def stereo_to_depth(img_left,img_right,P0,P1,matcher="bm", verbose=False, rectification=True):
    #compute the disparity map
    disparity= compute_disparity_map(img_left,img_right,verbose=True)

    #compute k,r,t
    k_left,r_left,t_left= decomposeProjectionMatrix(P0)
    k_right,r_right,t_right= decomposeProjectionMatrix(P1)

    #compute the depth map
    depth= compute_depth_map(disparity, k_left, t_left, t_right, rectification)
    
    return depth

# %%
def extract_features(img1,detector_name= "orb", verbose=False):
    
    if detector_name== "orb":
        detector= cv2.ORB.create()
    elif detector_name=="sift":
        detector= cv2.SIFT.create()
    else:
        print("Not valid detector")
        
    start= datetime.datetime.now()
    kp,des= detector.detectAndCompute(img1, mask=None)
    end= datetime.datetime.now()    

    if verbose:
        print(f"Time for extracting features with detector {detector}: {end-start}\n")
    
    return kp, des

# %%
def match_features(des1,des2, matcher="BF", detector="orb", verbose=False):
    if matcher== "BF":
        if detector == "orb":
            bf = cv2.BFMatcher.create(cv2.NORM_HAMMING, crossCheck=False)
        elif detector== "sift":
            bf = cv2.BFMatcher.create(cv2.NORM_L2, crossCheck=False)
        else:
            print("Not valid detector")
    elif matcher=="FLANN":
        #WIP
        pass
    else:
        print("Not valid matcher")
    start= datetime.datetime.now()
    matches= bf.knnMatch(des1,des2, k=2)
    end= datetime.datetime.now()

    if verbose:
        print(f"Time for matching features with matcher {matcher} and detector {detector}: {end-start}")

    return matches

# %%
#ratio test
def filter_matches(matches,threshold):
    filter_matches=[]
    for x, y in matches:
        if x.distance <= y.distance*threshold:
            filter_matches.append(x)
    return filter_matches

# %%
def visualize_matches(img1,kp1,img2,kp2,matches, flags=2):
    match_img= cv2.drawMatches(img1,kp1,img2,kp2,matches,None,flags, matchColor= (100,255,100))
    plt.figure(figsize=(16,6),dpi=100)
    plt.imshow(match_img)

# %%
def estimate_motion(kp1,kp2,k,matches,depth, max_depth=3000):
    #compute the image in pixel  
    image_points1= [kp1[m.queryIdx].pt for m in matches]
    image_points2= [kp2[m.trainIdx].pt for m in matches]

    # extracting parameters from k
    fx=k[0][0]
    fy=k[1][1]
    cx=k[0][2]
    cy=k[1][2]

    #converting interesting image_points1 from 2d to 3d
    objects_list=np.zeros((0,3))
    delete=[]

    for i , (u,v) in enumerate(image_points1):
        z= depth[int(round(v))][int(round(u))]

        if z >= max_depth:
            delete.append(i)
            continue

        x= z*(u-cx)/fx
        y= z*(v-cy)/fy
        objects_list= np.vstack([objects_list, np.array([x,y,z])])

    image_points1= np.delete(image_points1, delete, 0)
    image_points2= np.delete(image_points2, delete, 0)

    _, rvec,tvec, inliers= cv2.solvePnPRansac(objects_list, image_points2, k, None)
    rvec = cv2.Rodrigues(rvec)[0]
    
    return rvec, tvec

# %%
def visual_odometry(handler, stereo_matcher="bm", detector= "orb", matcher="BF", filter_threshold=None, mask= True, 
                    verbose=False, plot=True):
    print(f"Computing disparityMap with stereo_matcher : {stereo_matcher}")
    print(f"Detecting features with detector {detector}")
    print(f"Matching features with {matcher} and filtered with ratio test at threshold : {filter_threshold}")

    if plot:
        fig = plt.figure(figsize=(14, 14))
        ax = fig.add_subplot(projection='3d')
        ax.view_init(elev=-20, azim=270)
        xs = handler.poses[:, 0, 3]
        ys = handler.poses[:, 1, 3]
        zs = handler.poses[:, 2, 3]
        ax.set_box_aspect((np.ptp(xs), np.ptp(ys), np.ptp(zs)))
        ax.plot(xs, ys, zs, c='k')        
        
    num_frames= handler.num_frames
    
    k_left,r_left,t_left = decomposeProjectionMatrix(handler.P0)

    trajectory=np.zeros((num_frames, 3,4))
    #print(trajectory)
    T_tot=np.eye(4)
    trajectory[0]=(T_tot[:3,:])

    #Compute the trajectory for every frame
    for i in range(num_frames-1):
        start=datetime.datetime.now()
        
        left_img=handler.left_images[i]
        right_img=handler.right_images[i]
        left_imgplus1=handler.left_images[i+1]

        depth= stereo_to_depth(left_img, right_img, handler.P0, handler.P1)
        #
        kp0,des0 = extract_features(left_img)
        kp1,des1 = extract_features(left_imgplus1)

        #okk

        unmatched_features= match_features(des0,des1)

        print(f"Numero features senza filtering: {len(unmatched_features)}")

        if filter_threshold is not None :
            matched_features=filter_matches(unmatched_features, filter_threshold)
        else:
            matched_features= unmatched_features #problem : list of 2-element list, ransac doesn't want it

        print(f"Numero features con filtering: {len(matched_features)}")
        #okk
        
        rvec,tvec= estimate_motion(kp0,kp1,k_left, matched_features, depth)
        
        #computing the transformation matrix [rvec| tvec]
        T_mat= np.hstack([rvec,tvec])

        #computing the homogeneous transformation matrix, so then I can invert it
        T_mat=np.vstack([T_mat, [0,0,0,1]])

        #inverting the transformation matrix
        T_mat=np.linalg.inv(T_mat)

        T_tot = T_tot.dot(T_mat)

        #appending T_tot into trajectory

        trajectory[i+1, :, :] = T_tot[:3][:]
        end=datetime.datetime.now()
        print(f"Frame {i+1} processato. Tempo trascorso: {end-start}")

        print(f"\n {trajectory[i+1,:,:].round(4)}\n\n\n")

        if plot:
            xs = trajectory[:i+2, 0, 3]
            ys = trajectory[:i+2, 1, 3]
            zs = trajectory[:i+2, 2, 3]
            plt.plot(xs, ys, zs, c='chartreuse')
            plt.pause(1e-32)

    if plot:
        plt.close()

    return trajectory

# %%
def calculate_error(ground_truth, estimated, error_type='mse'):
    '''
    Takes arrays of ground truth and estimated poses of shape Nx3x4, and computes error using
    Euclidean distance between true and estimated 3D coordinate at each position.
    
    Arguments:
    ground_truth -- Nx3x4 array of ground truth poses
    estimated -- Nx3x4 array of estimated poses
    
    Optional Arguments:
    error_type -- (str) can be 'mae', 'mse', 'rmse', or 'all' to return dictionary of all 3
    
    Returns:
    error -- either a float or dictionary of error types and float values
    
    '''
    # Find the number of frames in the estimated trajectory to compare with
    nframes_est = estimated.shape[0]
    
    def get_mse(ground_truth, estimated):
        se = np.sqrt((ground_truth[nframes_est, 0, 3] - estimated[:, 0, 3])**2 
                    + (ground_truth[nframes_est, 1, 3] - estimated[:, 1, 3])**2 
                    + (ground_truth[nframes_est, 2, 3] - estimated[:, 2, 3])**2)**2
        mse = se.mean()
        return mse
    
    def get_mae(ground_truth, estimated):
        ae = np.sqrt((ground_truth[nframes_est, 0, 3] - estimated[:, 0, 3])**2 
                    + (ground_truth[nframes_est, 1, 3] - estimated[:, 1, 3])**2 
                    + (ground_truth[nframes_est, 2, 3] - estimated[:, 2, 3])**2)
        mae = ae.mean()
        return mae
    
    if error_type == 'mae':
        return get_mae(ground_truth, estimated)
    elif error_type == 'mse':
        return get_mse(ground_truth, estimated)
    elif error_type == 'rmse':
        return np.sqrt(get_mse(ground_truth, estimated))
    elif error_type == 'all':
        mae = get_mae(ground_truth, estimated)
        mse = get_mse(ground_truth, estimated)
        rmse = np.sqrt(mse)
        return {'mae': mae,
                'rmse': rmse,
                'mse': mse}

# %%
def main():
    calib_path="KITTI_dataset/sequences/00/calib.txt"
    images_path="KITTI_dataset/sequences/00/"
    gtPoses_path="KITTI_dataset/poses/00.txt"
    handler = Dataset_Handler(calib_path,images_path,gtPoses_path)
    trajectory= visual_odometry(handler, filter_threshold=0.5)

# %%
if __name__ == "__main__":
    main()
# Out:
# Loading images, just a moment...: 100%|████████████████████████████████████████████| 4541/4541 [02:09<00:00, 34.99it/s]
# Computing disparityMap with stereo_matcher : bm
# Detecting features with detector orb
# Matching features with BF and filtered with ratio test at threshold : 0.5
# Tempo impiegato da bm:
# 0:00:00.011257
# Numero features senza filtering: 500
# Numero features con filtering: 106
# Frame 1 processato. Tempo trascorso: 0:00:00.032046
#
#  [[ 1.     -0.0026 -0.0028 -0.0261]
#  [ 0.0026  1.     -0.0023 -0.005 ]
#  [ 0.0028  0.0023  1.      0.6479]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.010026
# Numero features senza filtering: 500
# Numero features con filtering: 122
# Frame 2 processato. Tempo trascorso: 0:00:00.033612
#
#  [[ 1.     -0.0022 -0.0043 -0.1192]
#  [ 0.0022  1.     -0.0034 -0.018 ]
#  [ 0.0043  0.0034  1.      1.2966]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.008284
# Numero features senza filtering: 500
# Numero features con filtering: 118
# Frame 3 processato. Tempo trascorso: 0:00:00.035415
#
#  [[ 1.     -0.0025 -0.0078 -0.1393]
#  [ 0.0025  1.     -0.0046 -0.0247]
#  [ 0.0078  0.0046  1.      2.0079]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.020410
# Numero features senza filtering: 500
# Numero features con filtering: 104
# Frame 4 processato. Tempo trascorso: 0:00:00.044071
#
#  [[ 9.9990e-01 -2.0000e-03 -1.1600e-02 -1.7690e-01]
#  [ 2.0000e-03  1.0000e+00 -4.8000e-03 -3.8700e-02]
#  [ 1.1600e-02  4.7000e-03  9.9990e-01  2.7087e+00]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013943
# Numero features senza filtering: 500
# Numero features con filtering: 98
# Frame 5 processato. Tempo trascorso: 0:00:00.035448
#
#  [[ 9.9990e-01 -2.8000e-03 -1.5900e-02 -2.0000e-01]
#  [ 2.7000e-03  1.0000e+00 -5.1000e-03 -4.3100e-02]
#  [ 1.5900e-02  5.0000e-03  9.9990e-01  3.4395e+00]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012183
# Numero features senza filtering: 500
# Numero features con filtering: 97
# Frame 6 processato. Tempo trascorso: 0:00:00.035247
#
#  [[ 9.9980e-01 -9.0000e-04 -2.0200e-02 -2.2740e-01]
#  [ 8.0000e-04  1.0000e+00 -5.8000e-03 -6.2800e-02]
#  [ 2.0200e-02  5.8000e-03  9.9980e-01  4.2008e+00]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.011186
# Numero features senza filtering: 500
# Numero features con filtering: 91
# Frame 7 processato. Tempo trascorso: 0:00:00.033537
#
#  [[ 9.9980e-01 -7.0000e-04 -1.9800e-02 -4.2770e-01]
#  [ 6.0000e-04  1.0000e+00 -4.2000e-03 -1.2030e-01]
#  [ 1.9800e-02  4.2000e-03  9.9980e-01  4.8281e+00]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.011516
# Numero features senza filtering: 500
# Numero features con filtering: 86
# Frame 8 processato. Tempo trascorso: 0:00:00.034068
#
#  [[ 9.9970e-01  3.0000e-04 -2.3500e-02 -4.6410e-01]
#  [-3.0000e-04  1.0000e+00 -2.4000e-03 -1.3740e-01]
#  [ 2.3500e-02  2.4000e-03  9.9970e-01  5.6086e+00]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.025764
# Numero features senza filtering: 500
# Numero features con filtering: 103
# Frame 9 processato. Tempo trascorso: 0:00:00.072478
#
#  [[ 9.9960e-01 -1.8000e-03 -2.8100e-02 -5.0400e-01]
#  [ 1.8000e-03  1.0000e+00  1.0000e-04 -1.3380e-01]
#  [ 2.8100e-02 -2.0000e-04  9.9960e-01  6.4148e+00]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.021730
# Numero features senza filtering: 500
# Numero features con filtering: 92
# Frame 10 processato. Tempo trascorso: 0:00:00.042300
#
#  [[ 9.9950e-01 -7.0000e-04 -3.0800e-02 -5.6510e-01]
#  [ 8.0000e-04  1.0000e+00  2.9000e-03 -1.4600e-01]
#  [ 3.0800e-02 -2.9000e-03  9.9950e-01  7.2504e+00]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.006008
# Numero features senza filtering: 500
# Numero features con filtering: 114
# Frame 11 processato. Tempo trascorso: 0:00:00.031834
#
#  [[ 9.9940e-01  8.0000e-04 -3.3400e-02 -6.0380e-01]
#  [-8.0000e-04  1.0000e+00  2.3000e-03 -1.5830e-01]
#  [ 3.3400e-02 -2.3000e-03  9.9940e-01  8.0522e+00]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.018551
# Numero features senza filtering: 500
# Numero features con filtering: 115
# Frame 12 processato. Tempo trascorso: 0:00:00.042682
#
#  [[ 9.994e-01 -2.000e-04 -3.510e-02 -6.582e-01]
#  [ 3.000e-04  1.000e+00  2.100e-03 -1.617e-01]
#  [ 3.510e-02 -2.100e-03  9.994e-01  8.852e+00]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.010996
# Numero features senza filtering: 500
# Numero features con filtering: 108
# Frame 13 processato. Tempo trascorso: 0:00:00.033024
#
#  [[ 9.9940e-01 -2.4000e-03 -3.5500e-02 -7.3620e-01]
#  [ 2.4000e-03  1.0000e+00  1.6000e-03 -1.6810e-01]
#  [ 3.5500e-02 -1.7000e-03  9.9940e-01  9.6773e+00]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.010015
# Numero features senza filtering: 500
# Numero features con filtering: 107
# Frame 14 processato. Tempo trascorso: 0:00:00.033607
#
#  [[ 9.99300e-01 -1.30000e-03 -3.76000e-02 -7.69800e-01]
#  [ 1.40000e-03  1.00000e+00  2.50000e-03 -1.81900e-01]
#  [ 3.76000e-02 -2.50000e-03  9.99300e-01  1.05261e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013503
# Numero features senza filtering: 500
# Numero features con filtering: 106
# Frame 15 processato. Tempo trascorso: 0:00:00.035921
#
#  [[ 9.99200e-01 -1.80000e-03 -3.88000e-02 -8.18000e-01]
#  [ 1.90000e-03  1.00000e+00  2.20000e-03 -1.93500e-01]
#  [ 3.87000e-02 -2.20000e-03  9.99200e-01  1.13807e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012528
# Numero features senza filtering: 500
# Numero features con filtering: 115
# Frame 16 processato. Tempo trascorso: 0:00:00.031848
#
#  [[ 9.99200e-01  8.00000e-04 -4.03000e-02 -8.63800e-01]
#  [-8.00000e-04  1.00000e+00 -1.00000e-04 -1.97400e-01]
#  [ 4.03000e-02  2.00000e-04  9.99200e-01  1.22225e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.010329
# Numero features senza filtering: 500
# Numero features con filtering: 99
# Frame 17 processato. Tempo trascorso: 0:00:00.031530
#
#  [[ 9.99200e-01 -2.00000e-04 -4.07000e-02 -9.74600e-01]
#  [ 1.00000e-04  1.00000e+00 -2.80000e-03 -1.92700e-01]
#  [ 4.07000e-02  2.80000e-03  9.99200e-01  1.31729e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012022
# Numero features senza filtering: 500
# Numero features con filtering: 105
# Frame 18 processato. Tempo trascorso: 0:00:00.029222
#
#  [[ 9.99200e-01  2.50000e-03 -4.11000e-02 -1.11630e+00]
#  [-2.70000e-03  1.00000e+00 -4.60000e-03 -1.92700e-01]
#  [ 4.11000e-02  4.70000e-03  9.99100e-01  1.41721e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012002
# Numero features senza filtering: 500
# Numero features con filtering: 93
# Frame 19 processato. Tempo trascorso: 0:00:00.029914
#
#  [[ 9.9920e-01  3.6000e-03 -4.0300e-02 -1.2748e+00]
#  [-3.8000e-03  1.0000e+00 -4.6000e-03 -1.9670e-01]
#  [ 4.0300e-02  4.7000e-03  9.9920e-01  1.5201e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.020450
# Numero features senza filtering: 500
# Numero features con filtering: 84
# Frame 20 processato. Tempo trascorso: 0:00:00.039692
#
#  [[ 9.99100e-01  3.00000e-04 -4.14000e-02 -1.33320e+00]
#  [-4.00000e-04  1.00000e+00 -3.10000e-03 -1.99800e-01]
#  [ 4.14000e-02  3.10000e-03  9.99100e-01  1.61059e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013017
# Numero features senza filtering: 500
# Numero features con filtering: 91
# Frame 21 processato. Tempo trascorso: 0:00:00.036989
#
#  [[ 9.99100e-01  1.00000e-04 -4.24000e-02 -1.39620e+00]
#  [-1.00000e-04  1.00000e+00 -1.70000e-03 -2.05600e-01]
#  [ 4.24000e-02  1.70000e-03  9.99100e-01  1.70066e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.011265
# Numero features senza filtering: 500
# Numero features con filtering: 99
# Frame 22 processato. Tempo trascorso: 0:00:00.036884
#
#  [[ 9.99100e-01 -1.20000e-03 -4.31000e-02 -1.46140e+00]
#  [ 1.20000e-03  1.00000e+00 -1.40000e-03 -2.19400e-01]
#  [ 4.31000e-02  1.40000e-03  9.99100e-01  1.79334e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013102
# Numero features senza filtering: 500
# Numero features con filtering: 74
# Frame 23 processato. Tempo trascorso: 0:00:00.035182
#
#  [[ 9.99000e-01 -3.80000e-03 -4.48000e-02 -1.51780e+00]
#  [ 3.70000e-03  1.00000e+00 -1.90000e-03 -2.24200e-01]
#  [ 4.48000e-02  1.80000e-03  9.99000e-01  1.88482e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.011760
# Numero features senza filtering: 500
# Numero features con filtering: 87
# Frame 24 processato. Tempo trascorso: 0:00:00.033639
#
#  [[ 9.98900e-01 -5.00000e-03 -4.57000e-02 -1.55750e+00]
#  [ 4.90000e-03  1.00000e+00 -2.30000e-03 -2.38700e-01]
#  [ 4.57000e-02  2.00000e-03  9.99000e-01  1.97542e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012641
# Numero features senza filtering: 500
# Numero features con filtering: 74
# Frame 25 processato. Tempo trascorso: 0:00:00.043504
#
#  [[ 9.98900e-01 -4.50000e-03 -4.67000e-02 -1.58680e+00]
#  [ 4.40000e-03  1.00000e+00 -1.10000e-03 -2.40200e-01]
#  [ 4.67000e-02  9.00000e-04  9.98900e-01  2.06742e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012743
# Numero features senza filtering: 500
# Numero features con filtering: 71
# Frame 26 processato. Tempo trascorso: 0:00:00.044434
#
#  [[ 9.98900e-01 -2.90000e-03 -4.68000e-02 -1.65310e+00]
#  [ 3.00000e-03  1.00000e+00  1.90000e-03 -2.49600e-01]
#  [ 4.68000e-02 -2.10000e-03  9.98900e-01  2.16386e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.023980
# Numero features senza filtering: 500
# Numero features con filtering: 76
# Frame 27 processato. Tempo trascorso: 0:00:00.049690
#
#  [[ 9.98900e-01 -2.30000e-03 -4.62000e-02 -1.70770e+00]
#  [ 2.50000e-03  1.00000e+00  5.60000e-03 -2.55500e-01]
#  [ 4.62000e-02 -5.70000e-03  9.98900e-01  2.25882e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012656
# Numero features senza filtering: 500
# Numero features con filtering: 85
# Frame 28 processato. Tempo trascorso: 0:00:00.033369
#
#  [[ 9.9900e-01 -6.3000e-03 -4.4300e-02 -1.7677e+00]
#  [ 6.7000e-03  9.9990e-01  8.8000e-03 -2.5280e-01]
#  [ 4.4200e-02 -9.1000e-03  9.9900e-01  2.3533e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.009755
# Numero features senza filtering: 500
# Numero features con filtering: 82
# Frame 29 processato. Tempo trascorso: 0:00:00.033398
#
#  [[ 9.99100e-01 -3.20000e-03 -4.32000e-02 -1.76540e+00]
#  [ 3.60000e-03  9.99900e-01  9.60000e-03 -2.76700e-01]
#  [ 4.32000e-02 -9.80000e-03  9.99000e-01  2.43923e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017049
# Numero features senza filtering: 500
# Numero features con filtering: 100
# Frame 30 processato. Tempo trascorso: 0:00:00.046904
#
#  [[ 9.99100e-01 -2.00000e-03 -4.29000e-02 -1.72260e+00]
#  [ 2.30000e-03  1.00000e+00  7.20000e-03 -3.01500e-01]
#  [ 4.29000e-02 -7.30000e-03  9.99100e-01  2.52215e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.014532
# Numero features senza filtering: 500
# Numero features con filtering: 89
# Frame 31 processato. Tempo trascorso: 0:00:00.048086
#
#  [[ 9.99100e-01 -9.00000e-04 -4.21000e-02 -1.78090e+00]
#  [ 1.00000e-03  1.00000e+00  2.30000e-03 -3.03400e-01]
#  [ 4.21000e-02 -2.40000e-03  9.99100e-01  2.61914e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.020060
# Numero features senza filtering: 500
# Numero features con filtering: 93
# Frame 32 processato. Tempo trascorso: 0:00:00.052523
#
#  [[ 9.99200e-01 -2.90000e-03 -4.10000e-02 -1.82420e+00]
#  [ 2.90000e-03  1.00000e+00 -6.00000e-04 -3.01700e-01]
#  [ 4.10000e-02  5.00000e-04  9.99200e-01  2.71393e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.016076
# Numero features senza filtering: 500
# Numero features con filtering: 84
# Frame 33 processato. Tempo trascorso: 0:00:00.045856
#
#  [[ 9.99200e-01 -4.30000e-03 -4.03000e-02 -1.86820e+00]
#  [ 4.30000e-03  1.00000e+00 -1.00000e-04 -3.06100e-01]
#  [ 4.03000e-02 -1.00000e-04  9.99200e-01  2.81177e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.016929
# Numero features senza filtering: 500
# Numero features con filtering: 92
# Frame 34 processato. Tempo trascorso: 0:00:00.044507
#
#  [[ 9.99100e-01 -4.60000e-03 -4.13000e-02 -1.86340e+00]
#  [ 4.90000e-03  1.00000e+00  5.10000e-03 -3.28700e-01]
#  [ 4.13000e-02 -5.30000e-03  9.99100e-01  2.90562e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015945
# Numero features senza filtering: 500
# Numero features con filtering: 95
# Frame 35 processato. Tempo trascorso: 0:00:00.047769
#
#  [[ 9.99100e-01 -7.70000e-03 -4.23000e-02 -1.91090e+00]
#  [ 8.10000e-03  9.99900e-01  8.60000e-03 -3.55700e-01]
#  [ 4.23000e-02 -9.00000e-03  9.99100e-01  3.00485e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017767
# Numero features senza filtering: 500
# Numero features con filtering: 106
# Frame 36 processato. Tempo trascorso: 0:00:00.047582
#
#  [[ 9.99000e-01 -1.45000e-02 -4.28000e-02 -1.98910e+00]
#  [ 1.48000e-02  9.99900e-01  7.70000e-03 -3.57800e-01]
#  [ 4.27000e-02 -8.30000e-03  9.99100e-01  3.10588e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.016123
# Numero features senza filtering: 500
# Numero features con filtering: 116
# Frame 37 processato. Tempo trascorso: 0:00:00.047924
#
#  [[ 9.98900e-01 -1.51000e-02 -4.46000e-02 -2.01150e+00]
#  [ 1.53000e-02  9.99900e-01  3.60000e-03 -3.63000e-01]
#  [ 4.46000e-02 -4.20000e-03  9.99000e-01  3.19923e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.031592
# Numero features senza filtering: 500
# Numero features con filtering: 130
# Frame 38 processato. Tempo trascorso: 0:00:00.063137
#
#  [[ 9.98800e-01 -1.35000e-02 -4.64000e-02 -2.04420e+00]
#  [ 1.35000e-02  9.99900e-01 -0.00000e+00 -3.98000e-01]
#  [ 4.64000e-02 -6.00000e-04  9.98900e-01  3.29581e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.021643
# Numero features senza filtering: 500
# Numero features con filtering: 110
# Frame 39 processato. Tempo trascorso: 0:00:00.052486
#
#  [[ 9.98800e-01 -1.18000e-02 -4.85000e-02 -2.10110e+00]
#  [ 1.18000e-02  9.99900e-01 -2.00000e-04 -4.26900e-01]
#  [ 4.85000e-02 -4.00000e-04  9.98800e-01  3.39461e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013780
# Numero features senza filtering: 500
# Numero features con filtering: 124
# Frame 40 processato. Tempo trascorso: 0:00:00.045610
#
#  [[ 9.98700e-01 -1.05000e-02 -4.98000e-02 -2.11780e+00]
#  [ 1.06000e-02  9.99900e-01  1.30000e-03 -4.50000e-01]
#  [ 4.98000e-02 -1.80000e-03  9.98800e-01  3.49026e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013772
# Numero features senza filtering: 500
# Numero features con filtering: 105
# Frame 41 processato. Tempo trascorso: 0:00:00.047457
#
#  [[ 9.98600e-01 -5.70000e-03 -5.19000e-02 -2.11170e+00]
#  [ 6.00000e-03  1.00000e+00  4.80000e-03 -4.91400e-01]
#  [ 5.19000e-02 -5.10000e-03  9.98600e-01  3.58162e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017776
# Numero features senza filtering: 500
# Numero features con filtering: 120
# Frame 42 processato. Tempo trascorso: 0:00:00.049349
#
#  [[ 9.98500e-01 -3.60000e-03 -5.45000e-02 -2.09980e+00]
#  [ 4.00000e-03  1.00000e+00  6.50000e-03 -5.31900e-01]
#  [ 5.45000e-02 -6.70000e-03  9.98500e-01  3.67781e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.011769
# Numero features senza filtering: 500
# Numero features con filtering: 136
# Frame 43 processato. Tempo trascorso: 0:00:00.042514
#
#  [[ 9.98500e-01 -2.60000e-03 -5.46000e-02 -2.23700e+00]
#  [ 3.10000e-03  1.00000e+00  8.80000e-03 -5.31300e-01]
#  [ 5.46000e-02 -8.90000e-03  9.98500e-01  3.78735e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017250
# Numero features senza filtering: 500
# Numero features con filtering: 112
# Frame 44 processato. Tempo trascorso: 0:00:00.043620
#
#  [[ 9.98500e-01 -1.10000e-03 -5.51000e-02 -2.24340e+00]
#  [ 1.80000e-03  9.99900e-01  1.23000e-02 -5.69200e-01]
#  [ 5.50000e-02 -1.24000e-02  9.98400e-01  3.88017e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013771
# Numero features senza filtering: 500
# Numero features con filtering: 121
# Frame 45 processato. Tempo trascorso: 0:00:00.043743
#
#  [[ 9.98400e-01  6.60000e-03 -5.63000e-02 -2.26620e+00]
#  [-5.70000e-03  9.99900e-01  1.52000e-02 -6.01400e-01]
#  [ 5.64000e-02 -1.48000e-02  9.98300e-01  3.97502e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017524
# Numero features senza filtering: 500
# Numero features con filtering: 115
# Frame 46 processato. Tempo trascorso: 0:00:00.047285
#
#  [[ 9.98400e-01  6.70000e-03 -5.65000e-02 -2.33490e+00]
#  [-5.80000e-03  9.99900e-01  1.50000e-02 -6.19200e-01]
#  [ 5.66000e-02 -1.47000e-02  9.98300e-01  4.07595e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015734
# Numero features senza filtering: 500
# Numero features con filtering: 113
# Frame 47 processato. Tempo trascorso: 0:00:00.048370
#
#  [[ 9.98400e-01  6.60000e-03 -5.63000e-02 -2.39250e+00]
#  [-5.80000e-03  9.99900e-01  1.31000e-02 -6.13400e-01]
#  [ 5.64000e-02 -1.28000e-02  9.98300e-01  4.17396e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.023700
# Numero features senza filtering: 500
# Numero features con filtering: 126
# Frame 48 processato. Tempo trascorso: 0:00:00.051199
#
#  [[ 9.98400e-01  9.50000e-03 -5.63000e-02 -2.44570e+00]
#  [-8.90000e-03  9.99900e-01  1.11000e-02 -6.22900e-01]
#  [ 5.64000e-02 -1.06000e-02  9.98400e-01  4.27132e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.010983
# Numero features senza filtering: 500
# Numero features con filtering: 131
# Frame 49 processato. Tempo trascorso: 0:00:00.042821
#
#  [[ 9.98300e-01  9.80000e-03 -5.68000e-02 -2.52200e+00]
#  [-9.20000e-03  9.99900e-01  1.12000e-02 -6.27200e-01]
#  [ 5.69000e-02 -1.07000e-02  9.98300e-01  4.37259e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017770
# Numero features senza filtering: 500
# Numero features con filtering: 125
# Frame 50 processato. Tempo trascorso: 0:00:00.043169
#
#  [[ 9.98200e-01  9.10000e-03 -5.89000e-02 -2.51190e+00]
#  [-8.40000e-03  9.99900e-01  1.28000e-02 -6.53000e-01]
#  [ 5.90000e-02 -1.23000e-02  9.98200e-01  4.46341e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.021480
# Numero features senza filtering: 500
# Numero features con filtering: 128
# Frame 51 processato. Tempo trascorso: 0:00:00.053823
#
#  [[ 9.98200e-01  1.02000e-02 -5.99000e-02 -2.55650e+00]
#  [-9.40000e-03  9.99900e-01  1.40000e-02 -6.69800e-01]
#  [ 6.01000e-02 -1.35000e-02  9.98100e-01  4.56074e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017772
# Numero features senza filtering: 500
# Numero features con filtering: 118
# Frame 52 processato. Tempo trascorso: 0:00:00.043235
#
#  [[ 9.98000e-01  1.54000e-02 -6.17000e-02 -2.51310e+00]
#  [-1.48000e-02  9.99800e-01  1.08000e-02 -7.09900e-01]
#  [ 6.19000e-02 -9.90000e-03  9.98000e-01  4.64666e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017769
# Numero features senza filtering: 500
# Numero features con filtering: 132
# Frame 53 processato. Tempo trascorso: 0:00:00.049556
#
#  [[ 9.97700e-01  1.92000e-02 -6.45000e-02 -2.46820e+00]
#  [-1.88000e-02  9.99800e-01  7.40000e-03 -7.52900e-01]
#  [ 6.46000e-02 -6.10000e-03  9.97900e-01  4.72872e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.016118
# Numero features senza filtering: 500
# Numero features con filtering: 120
# Frame 54 processato. Tempo trascorso: 0:00:00.049613
#
#  [[ 9.97500e-01  2.35000e-02 -6.69000e-02 -2.41010e+00]
#  [-2.31000e-02  9.99700e-01  7.10000e-03 -8.09200e-01]
#  [ 6.71000e-02 -5.50000e-03  9.97700e-01  4.81254e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.025858
# Numero features senza filtering: 500
# Numero features con filtering: 92
# Frame 55 processato. Tempo trascorso: 0:00:00.058449
#
#  [[ 9.97500e-01  2.27000e-02 -6.66000e-02 -2.49300e+00]
#  [-2.20000e-02  9.99700e-01  1.04000e-02 -8.11100e-01]
#  [ 6.68000e-02 -8.90000e-03  9.97700e-01  4.91239e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.002999
# Numero features senza filtering: 500
# Numero features con filtering: 98
# Frame 56 processato. Tempo trascorso: 0:00:00.046635
#
#  [[ 9.9750e-01  2.1600e-02 -6.7500e-02 -2.5319e+00]
#  [-2.0800e-02  9.9970e-01  1.3600e-02 -8.3300e-01]
#  [ 6.7800e-02 -1.2200e-02  9.9760e-01  5.0087e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013634
# Numero features senza filtering: 500
# Numero features con filtering: 110
# Frame 57 processato. Tempo trascorso: 0:00:00.047213
#
#  [[ 9.97400e-01  2.22000e-02 -6.86000e-02 -2.55560e+00]
#  [-2.12000e-02  9.99700e-01  1.44000e-02 -8.61900e-01]
#  [ 6.89000e-02 -1.29000e-02  9.97500e-01  5.10237e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015779
# Numero features senza filtering: 500
# Numero features con filtering: 115
# Frame 58 processato. Tempo trascorso: 0:00:00.054441
#
#  [[ 9.97400e-01  2.08000e-02 -6.93000e-02 -2.60850e+00]
#  [-1.99000e-02  9.99700e-01  1.35000e-02 -8.83200e-01]
#  [ 6.95000e-02 -1.21000e-02  9.97500e-01  5.19659e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.025497
# Numero features senza filtering: 500
# Numero features con filtering: 138
# Frame 59 processato. Tempo trascorso: 0:00:00.059958
#
#  [[ 9.97300e-01  2.00000e-02 -7.06000e-02 -2.66070e+00]
#  [-1.92000e-02  9.99700e-01  1.29000e-02 -9.15300e-01]
#  [ 7.09000e-02 -1.15000e-02  9.97400e-01  5.29383e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.026683
# Numero features senza filtering: 500
# Numero features con filtering: 117
# Frame 60 processato. Tempo trascorso: 0:00:00.055275
#
#  [[ 9.97200e-01  1.98000e-02 -7.17000e-02 -2.72600e+00]
#  [-1.89000e-02  9.99700e-01  1.39000e-02 -9.21000e-01]
#  [ 7.19000e-02 -1.25000e-02  9.97300e-01  5.38707e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.030673
# Numero features senza filtering: 500
# Numero features con filtering: 116
# Frame 61 processato. Tempo trascorso: 0:00:00.056397
#
#  [[ 9.97200e-01  1.91000e-02 -7.25000e-02 -2.77340e+00]
#  [-1.78000e-02  9.99700e-01  1.82000e-02 -9.40000e-01]
#  [ 7.29000e-02 -1.68000e-02  9.97200e-01  5.47754e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015770
# Numero features senza filtering: 500
# Numero features con filtering: 114
# Frame 62 processato. Tempo trascorso: 0:00:00.041314
#
#  [[ 9.97100e-01  2.03000e-02 -7.32000e-02 -2.82020e+00]
#  [-1.86000e-02  9.99600e-01  2.34000e-02 -9.63900e-01]
#  [ 7.37000e-02 -2.19000e-02  9.97000e-01  5.56922e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017146
# Numero features senza filtering: 500
# Numero features con filtering: 127
# Frame 63 processato. Tempo trascorso: 0:00:00.043431
#
#  [[ 9.97000e-01  2.44000e-02 -7.37000e-02 -2.88890e+00]
#  [-2.26000e-02  9.99400e-01  2.56000e-02 -9.78900e-01]
#  [ 7.43000e-02 -2.39000e-02  9.97000e-01  5.66147e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.014777
# Numero features senza filtering: 500
# Numero features con filtering: 118
# Frame 64 processato. Tempo trascorso: 0:00:00.043823
#
#  [[ 9.96900e-01  2.51000e-02 -7.52000e-02 -2.96880e+00]
#  [-2.35000e-02  9.99500e-01  2.18000e-02 -9.62700e-01]
#  [ 7.57000e-02 -2.00000e-02  9.96900e-01  5.75838e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012614
# Numero features senza filtering: 500
# Numero features con filtering: 116
# Frame 65 processato. Tempo trascorso: 0:00:00.047006
#
#  [[ 9.96700e-01  2.62000e-02 -7.63000e-02 -3.08500e+00]
#  [-2.52000e-02  9.99600e-01  1.36000e-02 -9.34300e-01]
#  [ 7.66000e-02 -1.16000e-02  9.97000e-01  5.85526e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.023732
# Numero features senza filtering: 500
# Numero features con filtering: 122
# Frame 66 processato. Tempo trascorso: 0:00:00.050659
#
#  [[ 9.96600e-01  2.99000e-02 -7.69000e-02 -3.17190e+00]
#  [-2.94000e-02  9.99500e-01  8.60000e-03 -9.42800e-01]
#  [ 7.72000e-02 -6.30000e-03  9.97000e-01  5.94671e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013888
# Numero features senza filtering: 500
# Numero features con filtering: 129
# Frame 67 processato. Tempo trascorso: 0:00:00.039701
#
#  [[ 9.96300e-01  3.55000e-02 -7.77000e-02 -3.25890e+00]
#  [-3.49000e-02  9.99300e-01  9.40000e-03 -9.51100e-01]
#  [ 7.79000e-02 -6.70000e-03  9.96900e-01  6.03791e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017134
# Numero features senza filtering: 500
# Numero features con filtering: 139
# Frame 68 processato. Tempo trascorso: 0:00:00.044368
#
#  [[ 9.96200e-01  3.75000e-02 -7.82000e-02 -3.35550e+00]
#  [-3.66000e-02  9.99300e-01  1.18000e-02 -9.53400e-01]
#  [ 7.86000e-02 -8.90000e-03  9.96900e-01  6.12607e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017550
# Numero features senza filtering: 500
# Numero features con filtering: 152
# Frame 69 processato. Tempo trascorso: 0:00:00.047533
#
#  [[ 9.96100e-01  4.15000e-02 -7.74000e-02 -3.53360e+00]
#  [-4.05000e-02  9.99100e-01  1.36000e-02 -9.73900e-01]
#  [ 7.79000e-02 -1.04000e-02  9.96900e-01  6.22163e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.023828
# Numero features senza filtering: 500
# Numero features con filtering: 159
# Frame 70 processato. Tempo trascorso: 0:00:00.056363
#
#  [[ 9.96000e-01  4.20000e-02 -7.84000e-02 -3.60960e+00]
#  [-4.11000e-02  9.99100e-01  1.31000e-02 -9.67100e-01]
#  [ 7.89000e-02 -9.80000e-03  9.96800e-01  6.30612e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.021905
# Numero features senza filtering: 500
# Numero features con filtering: 149
# Frame 71 processato. Tempo trascorso: 0:00:00.047603
#
#  [[ 9.96000e-01  4.36000e-02 -7.79000e-02 -3.78090e+00]
#  [-4.27000e-02  9.99000e-01  1.38000e-02 -9.67000e-01]
#  [ 7.85000e-02 -1.05000e-02  9.96900e-01  6.39294e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012971
# Numero features senza filtering: 500
# Numero features con filtering: 124
# Frame 72 processato. Tempo trascorso: 0:00:00.033523
#
#  [[ 9.95900e-01  4.45000e-02 -7.89000e-02 -3.86680e+00]
#  [-4.35000e-02  9.98900e-01  1.45000e-02 -9.76400e-01]
#  [ 7.95000e-02 -1.10000e-02  9.96800e-01  6.47739e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012003
# Numero features senza filtering: 500
# Numero features con filtering: 154
# Frame 73 processato. Tempo trascorso: 0:00:00.032587
#
#  [[ 9.9580e-01  4.4900e-02 -8.0300e-02 -3.9473e+00]
#  [-4.3800e-02  9.9890e-01  1.5000e-02 -9.8360e-01]
#  [ 8.0900e-02 -1.1400e-02  9.9670e-01  6.5583e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.006627
# Numero features senza filtering: 500
# Numero features con filtering: 158
# Frame 74 processato. Tempo trascorso: 0:00:00.033911
#
#  [[ 9.95700e-01  4.43000e-02 -8.11000e-02 -4.03360e+00]
#  [-4.31000e-02  9.98900e-01  1.63000e-02 -9.90200e-01]
#  [ 8.18000e-02 -1.27000e-02  9.96600e-01  6.63849e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012400
# Numero features senza filtering: 500
# Numero features con filtering: 175
# Frame 75 processato. Tempo trascorso: 0:00:00.033680
#
#  [[ 9.95500e-01  4.76000e-02 -8.25000e-02 -4.10520e+00]
#  [-4.61000e-02  9.98800e-01  1.92000e-02 -1.00170e+00]
#  [ 8.33000e-02 -1.53000e-02  9.96400e-01  6.71761e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012374
# Numero features senza filtering: 500
# Numero features con filtering: 147
# Frame 76 processato. Tempo trascorso: 0:00:00.031200
#
#  [[ 9.95300e-01  4.87000e-02 -8.34000e-02 -4.18640e+00]
#  [-4.70000e-02  9.98600e-01  2.31000e-02 -9.86700e-01]
#  [ 8.44000e-02 -1.91000e-02  9.96200e-01  6.79601e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.023118
# Numero features senza filtering: 500
# Numero features con filtering: 150
# Frame 77 processato. Tempo trascorso: 0:00:00.045016
#
#  [[ 9.95000e-01  5.25000e-02 -8.50000e-02 -4.25800e+00]
#  [-5.06000e-02  9.98400e-01  2.48000e-02 -9.89600e-01]
#  [ 8.62000e-02 -2.04000e-02  9.96100e-01  6.87361e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.011702
# Numero features senza filtering: 500
# Numero features con filtering: 145
# Frame 78 processato. Tempo trascorso: 0:00:00.031485
#
#  [[ 9.94700e-01  5.53000e-02 -8.62000e-02 -4.34860e+00]
#  [-5.38000e-02  9.98300e-01  2.07000e-02 -9.89000e-01]
#  [ 8.72000e-02 -1.60000e-02  9.96100e-01  6.94818e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012885
# Numero features senza filtering: 500
# Numero features con filtering: 171
# Frame 79 processato. Tempo trascorso: 0:00:00.033884
#
#  [[ 9.9460e-01  5.5700e-02 -8.7400e-02 -4.4376e+00]
#  [-5.4700e-02  9.9840e-01  1.3500e-02 -9.8890e-01]
#  [ 8.8000e-02 -8.7000e-03  9.9610e-01  7.0209e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017594
# Numero features senza filtering: 500
# Numero features con filtering: 179
# Frame 80 processato. Tempo trascorso: 0:00:00.039635
#
#  [[ 9.94500e-01  5.54000e-02 -8.88000e-02 -4.51760e+00]
#  [-5.50000e-02  9.98500e-01  7.70000e-03 -9.91300e-01]
#  [ 8.91000e-02 -2.80000e-03  9.96000e-01  7.09239e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015143
# Numero features senza filtering: 500
# Numero features con filtering: 195
# Frame 81 processato. Tempo trascorso: 0:00:00.030850
#
#  [[ 9.94400e-01  5.61000e-02 -8.93000e-02 -4.58690e+00]
#  [-5.57000e-02  9.98400e-01  6.60000e-03 -9.93600e-01]
#  [ 8.96000e-02 -1.60000e-03  9.96000e-01  7.16201e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013017
# Numero features senza filtering: 500
# Numero features con filtering: 203
# Frame 82 processato. Tempo trascorso: 0:00:00.034708
#
#  [[ 9.94300e-01  5.87000e-02 -8.86000e-02 -4.70520e+00]
#  [-5.80000e-02  9.98300e-01  1.02000e-02 -1.00240e+00]
#  [ 8.90000e-02 -5.00000e-03  9.96000e-01  7.22869e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.009579
# Numero features senza filtering: 500
# Numero features con filtering: 207
# Frame 83 processato. Tempo trascorso: 0:00:00.033516
#
#  [[ 9.9420e-01  5.8700e-02 -8.9500e-02 -4.7759e+00]
#  [-5.7800e-02  9.9820e-01  1.2600e-02 -1.0149e+00]
#  [ 9.0100e-02 -7.3000e-03  9.9590e-01  7.2937e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015684
# Numero features senza filtering: 500
# Numero features con filtering: 224
# Frame 84 processato. Tempo trascorso: 0:00:00.043651
#
#  [[ 9.94400e-01  5.59000e-02 -9.02000e-02 -4.85600e+00]
#  [-5.53000e-02  9.98400e-01  8.90000e-03 -1.00790e+00]
#  [ 9.06000e-02 -3.80000e-03  9.95900e-01  7.35816e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.002998
# Numero features senza filtering: 500
# Numero features con filtering: 209
# Frame 85 processato. Tempo trascorso: 0:00:00.036588
#
#  [[ 9.9470e-01  4.8000e-02 -9.0500e-02 -4.9031e+00]
#  [-4.7900e-02  9.9880e-01  3.7000e-03 -1.0196e+00]
#  [ 9.0600e-02  6.0000e-04  9.9590e-01  7.4191e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.019804
# Numero features senza filtering: 500
# Numero features con filtering: 193
# Frame 86 processato. Tempo trascorso: 0:00:00.041579
#
#  [[ 9.9510e-01  4.4100e-02 -8.8700e-02 -4.9834e+00]
#  [-4.4400e-02  9.9900e-01 -1.3000e-03 -1.0223e+00]
#  [ 8.8600e-02  5.2000e-03  9.9610e-01  7.4792e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.010784
# Numero features senza filtering: 500
# Numero features con filtering: 204
# Frame 87 processato. Tempo trascorso: 0:00:00.035639
#
#  [[ 9.95300e-01  4.69000e-02 -8.43000e-02 -5.08470e+00]
#  [-4.72000e-02  9.98900e-01 -1.60000e-03 -1.02940e+00]
#  [ 8.41000e-02  5.60000e-03  9.96400e-01  7.53617e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.023049
# Numero features senza filtering: 500
# Numero features con filtering: 189
# Frame 88 processato. Tempo trascorso: 0:00:00.043502
#
#  [[ 9.95500e-01  5.08000e-02 -7.95000e-02 -5.16200e+00]
#  [-5.09000e-02  9.98700e-01  1.30000e-03 -1.03470e+00]
#  [ 7.95000e-02  2.70000e-03  9.96800e-01  7.59348e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.020620
# Numero features senza filtering: 500
# Numero features con filtering: 201
# Frame 89 processato. Tempo trascorso: 0:00:00.039449
#
#  [[ 9.95900e-01  4.96000e-02 -7.61000e-02 -5.15480e+00]
#  [-4.95000e-02  9.98800e-01  4.00000e-03 -1.04110e+00]
#  [ 7.62000e-02 -3.00000e-04  9.97100e-01  7.64847e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.014955
# Numero features senza filtering: 500
# Numero features con filtering: 205
# Frame 90 processato. Tempo trascorso: 0:00:00.045858
#
#  [[ 9.96500e-01  4.61000e-02 -6.99000e-02 -5.20050e+00]
#  [-4.56000e-02  9.98900e-01  8.10000e-03 -1.04890e+00]
#  [ 7.02000e-02 -4.90000e-03  9.97500e-01  7.70252e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015962
# Numero features senza filtering: 500
# Numero features con filtering: 188
# Frame 91 processato. Tempo trascorso: 0:00:00.035745
#
#  [[ 9.97300e-01  4.14000e-02 -6.14000e-02 -5.22880e+00]
#  [-4.08000e-02  9.99100e-01  1.13000e-02 -1.06440e+00]
#  [ 6.18000e-02 -8.80000e-03  9.98000e-01  7.75389e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.009525
# Numero features senza filtering: 500
# Numero features con filtering: 199
# Frame 92 processato. Tempo trascorso: 0:00:00.035458
#
#  [[ 9.97700e-01  4.50000e-02 -5.05000e-02 -5.26210e+00]
#  [-4.45000e-02  9.99000e-01  1.08000e-02 -1.06740e+00]
#  [ 5.10000e-02 -8.50000e-03  9.98700e-01  7.80534e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013001
# Numero features senza filtering: 500
# Numero features con filtering: 181
# Frame 93 processato. Tempo trascorso: 0:00:00.032971
#
#  [[ 9.98100e-01  5.02000e-02 -3.56000e-02 -5.27990e+00]
#  [-4.99000e-02  9.98700e-01  1.00000e-02 -1.07620e+00]
#  [ 3.60000e-02 -8.20000e-03  9.99300e-01  7.85478e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.010901
# Numero features senza filtering: 500
# Numero features con filtering: 171
# Frame 94 processato. Tempo trascorso: 0:00:00.031612
#
#  [[ 9.98300e-01  5.57000e-02 -1.75000e-02 -5.28420e+00]
#  [-5.55000e-02  9.98400e-01  9.40000e-03 -1.07750e+00]
#  [ 1.80000e-02 -8.40000e-03  9.99800e-01  7.90358e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.027219
# Numero features senza filtering: 500
# Numero features con filtering: 162
# Frame 95 processato. Tempo trascorso: 0:00:00.047868
#
#  [[ 9.98500e-01  5.45000e-02  4.70000e-03 -5.27470e+00]
#  [-5.45000e-02  9.98500e-01  8.90000e-03 -1.07680e+00]
#  [-4.20000e-03 -9.10000e-03  9.99900e-01  7.95166e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00
# Numero features senza filtering: 500
# Numero features con filtering: 152
# Frame 96 processato. Tempo trascorso: 0:00:00.032270
#
#  [[ 9.98300e-01  5.03000e-02  3.08000e-02 -5.22940e+00]
#  [-5.06000e-02  9.98700e-01  9.20000e-03 -1.08640e+00]
#  [-3.03000e-02 -1.07000e-02  9.99500e-01  7.99687e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.009264
# Numero features senza filtering: 500
# Numero features con filtering: 141
# Frame 97 processato. Tempo trascorso: 0:00:00.031372
#
#  [[ 9.96900e-01  5.05000e-02  6.06000e-02 -5.19210e+00]
#  [-5.11000e-02  9.98700e-01  8.90000e-03 -1.07660e+00]
#  [-6.01000e-02 -1.20000e-02  9.98100e-01  8.04101e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012955
# Numero features senza filtering: 500
# Numero features con filtering: 143
# Frame 98 processato. Tempo trascorso: 0:00:00.032461
#
#  [[ 9.94400e-01  4.99000e-02  9.33000e-02 -5.11870e+00]
#  [-5.10000e-02  9.98700e-01  9.30000e-03 -1.08540e+00]
#  [-9.27000e-02 -1.40000e-02  9.95600e-01  8.08585e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.008870
# Numero features senza filtering: 500
# Numero features con filtering: 123
# Frame 99 processato. Tempo trascorso: 0:00:00.033141
#
#  [[ 9.90100e-01  5.02000e-02  1.30900e-01 -5.04010e+00]
#  [-5.17000e-02  9.98600e-01  8.00000e-03 -1.09310e+00]
#  [-1.30400e-01 -1.47000e-02  9.91400e-01  8.13024e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.025743
# Numero features senza filtering: 500
# Numero features con filtering: 124
# Frame 100 processato. Tempo trascorso: 0:00:00.031448
#
#  [[ 9.83700e-01  5.06000e-02  1.72300e-01 -4.93120e+00]
#  [-5.24000e-02  9.98600e-01  5.90000e-03 -1.08980e+00]
#  [-1.71800e-01 -1.48000e-02  9.85000e-01  8.17409e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.010038
# Numero features senza filtering: 500
# Numero features con filtering: 143
# Frame 101 processato. Tempo trascorso: 0:00:00.035976
#
#  [[ 9.74800e-01  5.06000e-02  2.17400e-01 -4.80410e+00]
#  [-5.27000e-02  9.98600e-01  3.80000e-03 -1.09910e+00]
#  [-2.16900e-01 -1.51000e-02  9.76100e-01  8.21674e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00
# Numero features senza filtering: 500
# Numero features con filtering: 120
# Frame 102 processato. Tempo trascorso: 0:00:00.031849
#
#  [[ 9.62000e-01  5.31000e-02  2.67700e-01 -4.71790e+00]
#  [-5.50000e-02  9.98500e-01 -3.00000e-04 -1.10790e+00]
#  [-2.67300e-01 -1.45000e-02  9.63500e-01  8.25267e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.011753
# Numero features senza filtering: 500
# Numero features con filtering: 151
# Frame 103 processato. Tempo trascorso: 0:00:00.031761
#
#  [[ 9.46000e-01  5.27000e-02  3.19700e-01 -4.54010e+00]
#  [-5.42000e-02  9.98500e-01 -4.40000e-03 -1.14270e+00]
#  [-3.19500e-01 -1.32000e-02  9.47500e-01  8.29088e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013998
# Numero features senza filtering: 500
# Numero features con filtering: 138
# Frame 104 processato. Tempo trascorso: 0:00:00.033008
#
#  [[ 9.25900e-01  5.10000e-02  3.74400e-01 -4.34520e+00]
#  [-5.20000e-02  9.98600e-01 -7.50000e-03 -1.17590e+00]
#  [-3.74300e-01 -1.25000e-02  9.27200e-01  8.32711e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.011761
# Numero features senza filtering: 500
# Numero features con filtering: 153
# Frame 105 processato. Tempo trascorso: 0:00:00.033843
#
#  [[ 9.0060e-01  5.1500e-02  4.3150e-01 -4.1500e+00]
#  [-5.1600e-02  9.9860e-01 -1.1600e-02 -1.1914e+00]
#  [-4.3150e-01 -1.1800e-02  9.0200e-01  8.3615e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.009516
# Numero features senza filtering: 500
# Numero features con filtering: 177
# Frame 106 processato. Tempo trascorso: 0:00:00.031555
#
#  [[ 8.70600e-01  5.28000e-02  4.89200e-01 -3.92880e+00]
#  [-5.09000e-02  9.98600e-01 -1.72000e-02 -1.18750e+00]
#  [-4.89400e-01 -9.90000e-03  8.72000e-01  8.39435e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012625
# Numero features senza filtering: 500
# Numero features con filtering: 185
# Frame 107 processato. Tempo trascorso: 0:00:00.034430
#
#  [[ 8.36200e-01  5.15000e-02  5.46000e-01 -3.68680e+00]
#  [-4.69000e-02  9.98700e-01 -2.23000e-02 -1.19810e+00]
#  [-5.46400e-01 -6.90000e-03  8.37500e-01  8.42456e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.020172
# Numero features senza filtering: 500
# Numero features con filtering: 160
# Frame 108 processato. Tempo trascorso: 0:00:00.035667
#
#  [[ 7.98300e-01  5.10000e-02  6.00100e-01 -3.43400e+00]
#  [-4.43000e-02  9.98700e-01 -2.59000e-02 -1.21600e+00]
#  [-6.00700e-01 -5.90000e-03  7.99500e-01  8.45262e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.009755
# Numero features senza filtering: 500
# Numero features con filtering: 149
# Frame 109 processato. Tempo trascorso: 0:00:00.035485
#
#  [[ 7.57100e-01  4.96000e-02  6.51500e-01 -3.17000e+00]
#  [-4.23000e-02  9.98700e-01 -2.69000e-02 -1.23810e+00]
#  [-6.52000e-01 -7.20000e-03  7.58200e-01  8.47853e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012893
# Numero features senza filtering: 500
# Numero features con filtering: 135
# Frame 110 processato. Tempo trascorso: 0:00:00.035297
#
#  [[ 7.13000e-01  4.95000e-02  6.99400e-01 -2.88360e+00]
#  [-4.25000e-02  9.98700e-01 -2.74000e-02 -1.25070e+00]
#  [-6.99900e-01 -1.03000e-02  7.14200e-01  8.50293e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.023821
# Numero features senza filtering: 500
# Numero features con filtering: 124
# Frame 111 processato. Tempo trascorso: 0:00:00.044719
#
#  [[ 6.67100e-01  4.89000e-02  7.43400e-01 -2.57710e+00]
#  [-4.10000e-02  9.98700e-01 -2.88000e-02 -1.26870e+00]
#  [-7.43800e-01 -1.13000e-02  6.68300e-01  8.52451e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015120
# Numero features senza filtering: 500
# Numero features con filtering: 134
# Frame 112 processato. Tempo trascorso: 0:00:00.034638
#
#  [[ 6.19700e-01  4.79000e-02  7.83400e-01 -2.25830e+00]
#  [-3.64000e-02  9.98800e-01 -3.23000e-02 -1.28840e+00]
#  [-7.84000e-01 -8.60000e-03  6.20700e-01  8.54437e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.014360
# Numero features senza filtering: 500
# Numero features con filtering: 148
# Frame 113 processato. Tempo trascorso: 0:00:00.035825
#
#  [[ 5.72100e-01  4.52000e-02  8.18900e-01 -1.92120e+00]
#  [-2.90000e-02  9.99000e-01 -3.49000e-02 -1.30910e+00]
#  [-8.19600e-01 -3.80000e-03  5.72900e-01  8.56244e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012911
# Numero features senza filtering: 500
# Numero features con filtering: 142
# Frame 114 processato. Tempo trascorso: 0:00:00.027566
#
#  [[ 5.24500e-01  4.74000e-02  8.50100e-01 -1.58950e+00]
#  [-2.97000e-02  9.98900e-01 -3.74000e-02 -1.33170e+00]
#  [-8.50900e-01 -5.60000e-03  5.25300e-01  8.57883e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015641
# Numero features senza filtering: 500
# Numero features con filtering: 155
# Frame 115 processato. Tempo trascorso: 0:00:00.039343
#
#  [[ 4.76100e-01  5.02000e-02  8.77900e-01 -1.24710e+00]
#  [-3.17000e-02  9.98700e-01 -4.00000e-02 -1.35360e+00]
#  [-8.78800e-01 -8.80000e-03  4.77100e-01  8.59458e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013001
# Numero features senza filtering: 500
# Numero features con filtering: 174
# Frame 116 processato. Tempo trascorso: 0:00:00.030985
#
#  [[ 4.30300e-01  5.24000e-02  9.01200e-01 -9.03900e-01]
#  [-2.97000e-02  9.98600e-01 -4.38000e-02 -1.37280e+00]
#  [-9.02200e-01 -7.90000e-03  4.31300e-01  8.60728e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.008012
# Numero features senza filtering: 500
# Numero features con filtering: 190
# Frame 117 processato. Tempo trascorso: 0:00:00.031299
#
#  [[ 3.87900e-01  5.00000e-02  9.20400e-01 -5.53500e-01]
#  [-2.07000e-02  9.98700e-01 -4.56000e-02 -1.39380e+00]
#  [-9.21500e-01 -1.40000e-03  3.88400e-01  8.61758e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.028444
# Numero features senza filtering: 500
# Numero features con filtering: 192
# Frame 118 processato. Tempo trascorso: 0:00:00.047220
#
#  [[ 3.48700e-01  4.27000e-02  9.36300e-01 -1.95300e-01]
#  [-4.10000e-03  9.99000e-01 -4.41000e-02 -1.41150e+00]
#  [-9.37200e-01  1.15000e-02  3.48600e-01  8.62562e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013788
# Numero features senza filtering: 500
# Numero features con filtering: 168
# Frame 119 processato. Tempo trascorso: 0:00:00.035075
#
#  [[ 3.13700e-01  3.91000e-02  9.48700e-01  1.36700e-01]
#  [ 2.00000e-03  9.99100e-01 -4.19000e-02 -1.43130e+00]
#  [-9.49500e-01  1.51000e-02  3.13300e-01  8.63189e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015906
# Numero features senza filtering: 500
# Numero features con filtering: 200
# Frame 120 processato. Tempo trascorso: 0:00:00.031972
#
#  [[ 2.80300e-01  4.32000e-02  9.58900e-01  4.98000e-01]
#  [ 1.20000e-03  9.99000e-01 -4.54000e-02 -1.45170e+00]
#  [-9.59900e-01  1.39000e-02  2.80000e-01  8.64045e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.019600
# Numero features senza filtering: 500
# Numero features con filtering: 170
# Frame 121 processato. Tempo trascorso: 0:00:00.047208
#
#  [[ 2.48900e-01  5.08000e-02  9.67200e-01  8.47700e-01]
#  [-7.70000e-03  9.98700e-01 -5.04000e-02 -1.47820e+00]
#  [-9.68500e-01  5.10000e-03  2.49000e-01  8.64859e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.011672
# Numero features senza filtering: 500
# Numero features con filtering: 182
# Frame 122 processato. Tempo trascorso: 0:00:00.023666
#
#  [[ 2.20600e-01  5.50000e-02  9.73800e-01  1.19420e+00]
#  [-1.10000e-02  9.98500e-01 -5.39000e-02 -1.50700e+00]
#  [-9.75300e-01  1.10000e-03  2.20900e-01  8.65474e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00
# Numero features senza filtering: 500
# Numero features con filtering: 189
# Frame 123 processato. Tempo trascorso: 0:00:00.041360
#
#  [[ 1.95200e-01  5.67000e-02  9.79100e-01  1.57710e+00]
#  [-8.60000e-03  9.98400e-01 -5.61000e-02 -1.53800e+00]
#  [-9.80700e-01  2.60000e-03  1.95400e-01  8.65928e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.020084
# Numero features senza filtering: 500
# Numero features con filtering: 177
# Frame 124 processato. Tempo trascorso: 0:00:00.055271
#
#  [[ 1.72400e-01  5.80000e-02  9.83300e-01  1.85150e+00]
#  [-0.00000e+00  9.98300e-01 -5.88000e-02 -1.56310e+00]
#  [-9.85000e-01  1.01000e-02  1.72100e-01  8.66227e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.019529
# Numero features senza filtering: 500
# Numero features con filtering: 190
# Frame 125 processato. Tempo trascorso: 0:00:00.051663
#
#  [[ 1.52900e-01  6.39000e-02  9.86200e-01  2.17130e+00]
#  [ 6.60000e-03  9.97800e-01 -6.57000e-02 -1.60130e+00]
#  [-9.88200e-01  1.66000e-02  1.52100e-01  8.66223e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013772
# Numero features senza filtering: 500
# Numero features con filtering: 194
# Frame 126 processato. Tempo trascorso: 0:00:00.053131
#
#  [[ 1.33500e-01  7.04000e-02  9.88500e-01  2.50220e+00]
#  [ 8.70000e-03  9.97400e-01 -7.22000e-02 -1.64140e+00]
#  [-9.91000e-01  1.82000e-02  1.32600e-01  8.66358e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.016120
# Numero features senza filtering: 500
# Numero features con filtering: 207
# Frame 127 processato. Tempo trascorso: 0:00:00.063396
#
#  [[ 1.16100e-01  7.09000e-02  9.90700e-01  2.93780e+00]
#  [ 7.60000e-03  9.97400e-01 -7.23000e-02 -1.67740e+00]
#  [-9.93200e-01  1.59000e-02  1.15200e-01  8.66754e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.014934
# Numero features senza filtering: 500
# Numero features con filtering: 187
# Frame 128 processato. Tempo trascorso: 0:00:00.049321
#
#  [[ 1.00800e-01  6.65000e-02  9.92700e-01  3.38940e+00]
#  [ 6.30000e-03  9.97700e-01 -6.75000e-02 -1.71760e+00]
#  [-9.94900e-01  1.31000e-02  1.00100e-01  8.66947e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.021731
# Numero features senza filtering: 500
# Numero features con filtering: 175
# Frame 129 processato. Tempo trascorso: 0:00:00.057822
#
#  [[ 8.64000e-02  6.30000e-02  9.94300e-01  3.77220e+00]
#  [ 7.00000e-03  9.97900e-01 -6.38000e-02 -1.76270e+00]
#  [-9.96200e-01  1.24000e-02  8.58000e-02  8.67139e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012148
# Numero features senza filtering: 500
# Numero features con filtering: 200
# Frame 130 processato. Tempo trascorso: 0:00:00.050710
#
#  [[ 7.36000e-02  6.07000e-02  9.95400e-01  4.28430e+00]
#  [ 1.10000e-02  9.98000e-01 -6.17000e-02 -1.79460e+00]
#  [-9.97200e-01  1.55000e-02  7.28000e-02  8.67384e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017637
# Numero features senza filtering: 500
# Numero features con filtering: 201
# Frame 131 processato. Tempo trascorso: 0:00:00.048720
#
#  [[ 6.23000e-02  6.00000e-02  9.96300e-01  4.80920e+00]
#  [ 1.59000e-02  9.98000e-01 -6.11000e-02 -1.82310e+00]
#  [-9.97900e-01  1.97000e-02  6.12000e-02  8.67641e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.016641
# Numero features senza filtering: 500
# Numero features con filtering: 209
# Frame 132 processato. Tempo trascorso: 0:00:00.048738
#
#  [[ 5.29000e-02  6.10000e-02  9.96700e-01  5.36360e+00]
#  [ 2.09000e-02  9.97800e-01 -6.22000e-02 -1.84050e+00]
#  [-9.98400e-01  2.42000e-02  5.15000e-02  8.67711e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.016030
# Numero features senza filtering: 500
# Numero features con filtering: 206
# Frame 133 processato. Tempo trascorso: 0:00:00.047784
#
#  [[ 4.54000e-02  6.15000e-02  9.97100e-01  5.86070e+00]
#  [ 2.39000e-02  9.97800e-01 -6.26000e-02 -1.87680e+00]
#  [-9.98700e-01  2.67000e-02  4.38000e-02  8.67761e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.018551
# Numero features senza filtering: 500
# Numero features con filtering: 220
# Frame 134 processato. Tempo trascorso: 0:00:00.057040
#
#  [[ 4.0000e-02  6.1900e-02  9.9730e-01  6.4117e+00]
#  [ 2.6100e-02  9.9770e-01 -6.3000e-02 -1.9138e+00]
#  [-9.9890e-01  2.8600e-02  3.8300e-02  8.6795e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015536
# Numero features senza filtering: 500
# Numero features con filtering: 201
# Frame 135 processato. Tempo trascorso: 0:00:00.049569
#
#  [[ 3.51000e-02  6.24000e-02  9.97400e-01  6.93270e+00]
#  [ 2.70000e-02  9.97600e-01 -6.34000e-02 -1.97070e+00]
#  [-9.99000e-01  2.92000e-02  3.34000e-02  8.67709e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017777
# Numero features senza filtering: 500
# Numero features con filtering: 198
# Frame 136 processato. Tempo trascorso: 0:00:00.053203
#
#  [[ 2.92000e-02  6.28000e-02  9.97600e-01  7.46270e+00]
#  [ 2.80000e-02  9.97600e-01 -6.36000e-02 -2.02000e+00]
#  [-9.99200e-01  2.98000e-02  2.74000e-02  8.67883e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.022387
# Numero features senza filtering: 500
# Numero features con filtering: 229
# Frame 137 processato. Tempo trascorso: 0:00:00.055003
#
#  [[ 2.52000e-02  6.29000e-02  9.97700e-01  8.01720e+00]
#  [ 3.01000e-02  9.97500e-01 -6.36000e-02 -2.05940e+00]
#  [-9.99200e-01  3.16000e-02  2.32000e-02  8.67793e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017878
# Numero features senza filtering: 500
# Numero features con filtering: 204
# Frame 138 processato. Tempo trascorso: 0:00:00.052614
#
#  [[ 2.2800e-02  6.3000e-02  9.9780e-01  8.6183e+00]
#  [ 3.2500e-02  9.9740e-01 -6.3800e-02 -2.1014e+00]
#  [-9.9920e-01  3.3900e-02  2.0700e-02  8.6775e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.022751
# Numero features senza filtering: 500
# Numero features con filtering: 193
# Frame 139 processato. Tempo trascorso: 0:00:00.052522
#
#  [[ 2.00000e-02  6.27000e-02  9.97800e-01  9.22190e+00]
#  [ 3.25000e-02  9.97500e-01 -6.33000e-02 -2.14190e+00]
#  [-9.99300e-01  3.37000e-02  1.80000e-02  8.67621e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017188
# Numero features senza filtering: 500
# Numero features con filtering: 203
# Frame 140 processato. Tempo trascorso: 0:00:00.050179
#
#  [[ 1.77000e-02  6.20000e-02  9.97900e-01  9.83770e+00]
#  [ 3.37000e-02  9.97500e-01 -6.25000e-02 -2.19200e+00]
#  [-9.99300e-01  3.47000e-02  1.56000e-02  8.67648e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.027788
# Numero features senza filtering: 500
# Numero features con filtering: 206
# Frame 141 processato. Tempo trascorso: 0:00:00.056208
#
#  [[ 1.77000e-02  6.20000e-02  9.97900e-01  1.05097e+01]
#  [ 3.86000e-02  9.97300e-01 -6.26000e-02 -2.22740e+00]
#  [-9.99100e-01  3.96000e-02  1.52000e-02  8.67610e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017039
# Numero features senza filtering: 500
# Numero features con filtering: 198
# Frame 142 processato. Tempo trascorso: 0:00:00.045033
#
#  [[ 1.87000e-02  6.18000e-02  9.97900e-01  1.12117e+01]
#  [ 4.24000e-02  9.97100e-01 -6.26000e-02 -2.27060e+00]
#  [-9.98900e-01  4.35000e-02  1.61000e-02  8.67782e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015777
# Numero features senza filtering: 500
# Numero features con filtering: 184
# Frame 143 processato. Tempo trascorso: 0:00:00.045381
#
#  [[ 2.12000e-02  6.14000e-02  9.97900e-01  1.19145e+01]
#  [ 4.31000e-02  9.97100e-01 -6.23000e-02 -2.34450e+00]
#  [-9.98800e-01  4.43000e-02  1.85000e-02  8.67889e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015143
# Numero features senza filtering: 500
# Numero features con filtering: 202
# Frame 144 processato. Tempo trascorso: 0:00:00.043214
#
#  [[ 2.47000e-02  6.15000e-02  9.97800e-01  1.26181e+01]
#  [ 4.45000e-02  9.97000e-01 -6.26000e-02 -2.39530e+00]
#  [-9.98700e-01  4.60000e-02  2.19000e-02  8.68127e+01]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015931
# Numero features senza filtering: 500
# ...
# Frame 1278 processato. Tempo trascorso: 0:00:00.066473
#
#  [[ 4.015000e-01  2.186000e-01  8.894000e-01 -9.284700e+01]
#  [-1.440000e-01  9.741000e-01 -1.745000e-01 -3.203400e+00]
#  [-9.045000e-01 -5.800000e-02  4.226000e-01  2.328761e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.009889
# Numero features senza filtering: 500
# Numero features con filtering: 205
# Frame 1279 processato. Tempo trascorso: 0:00:00.028162
#
#  [[ 3.709000e-01  2.178000e-01  9.028000e-01 -9.245130e+01]
#  [-1.344000e-01  9.745000e-01 -1.799000e-01 -3.288200e+00]
#  [-9.189000e-01 -5.460000e-02  3.907000e-01  2.330227e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015667
# Numero features senza filtering: 500
# Numero features con filtering: 178
# Frame 1280 processato. Tempo trascorso: 0:00:00.057029
#
#  [[ 3.44700e-01  2.19400e-01  9.12700e-01 -9.20340e+01]
#  [-1.26200e-01  9.74300e-01 -1.86500e-01 -3.36990e+00]
#  [-9.30200e-01 -5.09000e-02  3.63500e-01  2.33165e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.014551
# Numero features senza filtering: 500
# Numero features con filtering: 194
# Frame 1281 processato. Tempo trascorso: 0:00:00.060943
#
#  [[ 3.227000e-01  2.230000e-01  9.199000e-01 -9.168660e+01]
#  [-1.215000e-01  9.736000e-01 -1.934000e-01 -3.443700e+00]
#  [-9.387000e-01 -4.930000e-02  3.412000e-01  2.332994e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.016808
# Numero features senza filtering: 500
# Numero features con filtering: 165
# Frame 1282 processato. Tempo trascorso: 0:00:00.045504
#
#  [[ 3.045000e-01  2.274000e-01  9.250000e-01 -9.127290e+01]
#  [-1.196000e-01  9.725000e-01 -1.997000e-01 -3.535700e+00]
#  [-9.450000e-01 -4.980000e-02  3.234000e-01  2.334322e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012737
# Numero features senza filtering: 500
# Numero features con filtering: 167
# Frame 1283 processato. Tempo trascorso: 0:00:00.046376
#
#  [[ 2.895000e-01  2.316000e-01  9.287000e-01 -9.083610e+01]
#  [-1.176000e-01  9.715000e-01 -2.056000e-01 -3.629300e+00]
#  [-9.499000e-01 -4.970000e-02  3.085000e-01  2.335656e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015768
# Numero features senza filtering: 500
# Numero features con filtering: 165
# Frame 1284 processato. Tempo trascorso: 0:00:00.042246
#
#  [[ 2.752000e-01  2.359000e-01  9.320000e-01 -9.041460e+01]
#  [-1.161000e-01  9.705000e-01 -2.113000e-01 -3.722900e+00]
#  [-9.543000e-01 -5.000000e-02  2.945000e-01  2.336824e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012403
# Numero features senza filtering: 500
# Numero features con filtering: 152
# Frame 1285 processato. Tempo trascorso: 0:00:00.038858
#
#  [[ 2.608000e-01  2.389000e-01  9.354000e-01 -8.990690e+01]
#  [-1.136000e-01  9.698000e-01 -2.160000e-01 -3.829600e+00]
#  [-9.587000e-01 -4.990000e-02  2.801000e-01  2.338182e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.014737
# Numero features senza filtering: 500
# Numero features con filtering: 154
# Frame 1286 processato. Tempo trascorso: 0:00:00.040902
#
#  [[ 2.469000e-01  2.394000e-01  9.390000e-01 -8.945310e+01]
#  [-1.094000e-01  9.697000e-01 -2.185000e-01 -3.955600e+00]
#  [-9.629000e-01 -4.880000e-02  2.656000e-01  2.339585e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013808
# Numero features senza filtering: 500
# Numero features con filtering: 166
# Frame 1287 processato. Tempo trascorso: 0:00:00.046969
#
#  [[ 2.370000e-01  2.382000e-01  9.419000e-01 -8.890790e+01]
#  [-1.030000e-01  9.702000e-01 -2.194000e-01 -4.081100e+00]
#  [-9.660000e-01 -4.500000e-02  2.544000e-01  2.340971e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012658
# Numero features senza filtering: 500
# Numero features con filtering: 182
# Frame 1288 processato. Tempo trascorso: 0:00:00.039967
#
#  [[ 2.301000e-01  2.367000e-01  9.439000e-01 -8.838960e+01]
#  [-9.930000e-02  9.706000e-01 -2.192000e-01 -4.204500e+00]
#  [-9.681000e-01 -4.330000e-02  2.469000e-01  2.342287e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013748
# Numero features senza filtering: 500
# Numero features con filtering: 155
# Frame 1289 processato. Tempo trascorso: 0:00:00.040089
#
#  [[ 2.277000e-01  2.337000e-01  9.453000e-01 -8.784530e+01]
#  [-9.540000e-02  9.715000e-01 -2.172000e-01 -4.335400e+00]
#  [-9.691000e-01 -4.070000e-02  2.435000e-01  2.343753e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.016599
# Numero features senza filtering: 500
# Numero features con filtering: 163
# Frame 1290 processato. Tempo trascorso: 0:00:00.044084
#
#  [[ 2.264000e-01  2.311000e-01  9.462000e-01 -8.730740e+01]
#  [-9.650000e-02  9.720000e-01 -2.143000e-01 -4.465200e+00]
#  [-9.692000e-01 -4.280000e-02  2.424000e-01  2.345261e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.011809
# Numero features senza filtering: 500
# Numero features con filtering: 152
# Frame 1291 processato. Tempo trascorso: 0:00:00.039186
#
#  [[ 2.258000e-01  2.286000e-01  9.470000e-01 -8.674000e+01]
#  [-9.680000e-02  9.725000e-01 -2.117000e-01 -4.585500e+00]
#  [-9.694000e-01 -4.380000e-02  2.417000e-01  2.346699e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013880
# Numero features senza filtering: 500
# Numero features con filtering: 174
# Frame 1292 processato. Tempo trascorso: 0:00:00.042939
#
#  [[ 2.235000e-01  2.280000e-01  9.477000e-01 -8.616170e+01]
#  [-9.720000e-02  9.726000e-01 -2.111000e-01 -4.725200e+00]
#  [-9.698000e-01 -4.500000e-02  2.395000e-01  2.348221e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.026357
# Numero features senza filtering: 500
# Numero features con filtering: 156
# Frame 1293 processato. Tempo trascorso: 0:00:00.051111
#
#  [[ 2.216000e-01  2.282000e-01  9.480000e-01 -8.556390e+01]
#  [-9.840000e-02  9.725000e-01 -2.111000e-01 -4.866400e+00]
#  [-9.702000e-01 -4.650000e-02  2.380000e-01  2.349781e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.022924
# Numero features senza filtering: 500
# Numero features con filtering: 142
# Frame 1294 processato. Tempo trascorso: 0:00:00.048965
#
#  [[ 2.204000e-01  2.288000e-01  9.482000e-01 -8.495730e+01]
#  [-9.860000e-02  9.724000e-01 -2.117000e-01 -5.004000e+00]
#  [-9.704000e-01 -4.680000e-02  2.369000e-01  2.351223e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013789
# Numero features senza filtering: 500
# Numero features con filtering: 141
# Frame 1295 processato. Tempo trascorso: 0:00:00.037215
#
#  [[ 2.178000e-01  2.306000e-01  9.484000e-01 -8.432790e+01]
#  [-9.800000e-02  9.719000e-01 -2.138000e-01 -5.152100e+00]
#  [-9.711000e-01 -4.640000e-02  2.343000e-01  2.352911e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015484
# Numero features senza filtering: 500
# Numero features con filtering: 156
# Frame 1296 processato. Tempo trascorso: 0:00:00.038412
#
#  [[ 2.154000e-01  2.329000e-01  9.483000e-01 -8.367520e+01]
#  [-9.750000e-02  9.714000e-01 -2.164000e-01 -5.302200e+00]
#  [-9.716000e-01 -4.580000e-02  2.320000e-01  2.354493e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.011686
# Numero features senza filtering: 500
# Numero features con filtering: 162
# Frame 1297 processato. Tempo trascorso: 0:00:00.037289
#
#  [[ 2.123000e-01  2.351000e-01  9.485000e-01 -8.302320e+01]
#  [-9.840000e-02  9.708000e-01 -2.186000e-01 -5.460500e+00]
#  [-9.722000e-01 -4.700000e-02  2.293000e-01  2.356169e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.014753
# Numero features senza filtering: 500
# Numero features con filtering: 143
# Frame 1298 processato. Tempo trascorso: 0:00:00.040567
#
#  [[ 2.094000e-01  2.366000e-01  9.488000e-01 -8.235620e+01]
#  [-9.920000e-02  9.704000e-01 -2.201000e-01 -5.625200e+00]
#  [-9.728000e-01 -4.810000e-02  2.267000e-01  2.357797e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.011747
# Numero features senza filtering: 500
# Numero features con filtering: 133
# Frame 1299 processato. Tempo trascorso: 0:00:00.034457
#
#  [[ 2.071000e-01  2.370000e-01  9.492000e-01 -8.165750e+01]
#  [-1.005000e-01  9.702000e-01 -2.204000e-01 -5.782900e+00]
#  [-9.731000e-01 -4.970000e-02  2.247000e-01  2.359516e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.014414
# Numero features senza filtering: 500
# Numero features con filtering: 125
# Frame 1300 processato. Tempo trascorso: 0:00:00.037357
#
#  [[ 2.041000e-01  2.371000e-01  9.498000e-01 -8.094470e+01]
#  [-1.020000e-01  9.701000e-01 -2.203000e-01 -5.952200e+00]
#  [-9.736000e-01 -5.190000e-02  2.222000e-01  2.361364e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015248
# Numero features senza filtering: 500
# Numero features con filtering: 132
# Frame 1301 processato. Tempo trascorso: 0:00:00.037975
#
#  [[ 2.020000e-01  2.350000e-01  9.508000e-01 -8.028580e+01]
#  [-1.029000e-01  9.705000e-01 -2.180000e-01 -6.156900e+00]
#  [-9.740000e-01 -5.380000e-02  2.202000e-01  2.362654e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.017433
# Numero features senza filtering: 500
# Numero features con filtering: 138
# Frame 1302 processato. Tempo trascorso: 0:00:00.051433
#
#  [[ 2.00200e-01  2.33300e-01  9.51600e-01 -7.95647e+01]
#  [-1.00600e-01  9.71000e-01 -2.16900e-01 -6.32990e+00]
#  [-9.74600e-01 -5.23000e-02  2.17800e-01  2.36438e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015001
# Numero features senza filtering: 500
# Numero features con filtering: 139
# Frame 1303 processato. Tempo trascorso: 0:00:00.038891
#
#  [[ 1.977000e-01  2.319000e-01  9.524000e-01 -7.885460e+01]
#  [-9.820000e-02  9.714000e-01 -2.162000e-01 -6.498000e+00]
#  [-9.753000e-01 -5.080000e-02  2.149000e-01  2.365922e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.014835
# Numero features senza filtering: 500
# Numero features con filtering: 128
# Frame 1304 processato. Tempo trascorso: 0:00:00.036958
#
#  [[ 1.944000e-01  2.314000e-01  9.532000e-01 -7.821590e+01]
#  [-1.006000e-01  9.714000e-01 -2.153000e-01 -6.698000e+00]
#  [-9.757000e-01 -5.400000e-02  2.121000e-01  2.367114e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.014640
# Numero features senza filtering: 500
# Numero features con filtering: 153
# Frame 1305 processato. Tempo trascorso: 0:00:00.040784
#
#  [[ 1.918000e-01  2.320000e-01  9.536000e-01 -7.744720e+01]
#  [-1.008000e-01  9.712000e-01 -2.160000e-01 -6.885000e+00]
#  [-9.762000e-01 -5.470000e-02  2.097000e-01  2.368874e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.014674
# Numero features senza filtering: 500
# Numero features con filtering: 137
# Frame 1306 processato. Tempo trascorso: 0:00:00.036433
#
#  [[ 1.906000e-01  2.312000e-01  9.541000e-01 -7.666670e+01]
#  [-9.740000e-02  9.715000e-01 -2.160000e-01 -7.070100e+00]
#  [-9.768000e-01 -5.180000e-02  2.077000e-01  2.370654e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.014558
# Numero features senza filtering: 500
# Numero features con filtering: 140
# Frame 1307 processato. Tempo trascorso: 0:00:00.038457
#
#  [[ 1.890000e-01  2.313000e-01  9.544000e-01 -7.589240e+01]
#  [-9.670000e-02  9.715000e-01 -2.163000e-01 -7.255500e+00]
#  [-9.772000e-01 -5.140000e-02  2.059000e-01  2.372384e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.011672
# Numero features senza filtering: 500
# Numero features con filtering: 114
# Frame 1308 processato. Tempo trascorso: 0:00:00.032600
#
#  [[ 1.873000e-01  2.326000e-01  9.544000e-01 -7.512340e+01]
#  [-9.610000e-02  9.712000e-01 -2.178000e-01 -7.433800e+00]
#  [-9.776000e-01 -5.090000e-02  2.042000e-01  2.374066e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012923
# Numero features senza filtering: 500
# Numero features con filtering: 98
# Frame 1309 processato. Tempo trascorso: 0:00:00.033325
#
#  [[ 1.854000e-01  2.345000e-01  9.543000e-01 -7.433600e+01]
#  [-9.720000e-02  9.707000e-01 -2.197000e-01 -7.634500e+00]
#  [-9.779000e-01 -5.200000e-02  2.027000e-01  2.375843e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.013209
# Numero features senza filtering: 500
# Numero features con filtering: 100
# Frame 1310 processato. Tempo trascorso: 0:00:00.036990
#
#  [[ 1.838000e-01  2.380000e-01  9.537000e-01 -7.352850e+01]
#  [-9.770000e-02  9.699000e-01 -2.232000e-01 -7.825400e+00]
#  [-9.781000e-01 -5.220000e-02  2.015000e-01  2.377603e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.014379
# Numero features senza filtering: 500
# Numero features con filtering: 99
# Frame 1311 processato. Tempo trascorso: 0:00:00.051418
#
#  [[ 1.812000e-01  2.406000e-01  9.536000e-01 -7.273560e+01]
#  [-9.960000e-02  9.691000e-01 -2.255000e-01 -8.017200e+00]
#  [-9.784000e-01 -5.410000e-02  1.996000e-01  2.379359e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015186
# Numero features senza filtering: 500
# Numero features con filtering: 89
# Frame 1312 processato. Tempo trascorso: 0:00:00.038212
#
#  [[ 1.794000e-01  2.428000e-01  9.533000e-01 -7.192770e+01]
#  [-1.010000e-01  9.685000e-01 -2.277000e-01 -8.205700e+00]
#  [-9.786000e-01 -5.540000e-02  1.983000e-01  2.381095e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.026459
# Numero features senza filtering: 500
# Numero features con filtering: 108
# Frame 1313 processato. Tempo trascorso: 0:00:00.047822
#
#  [[ 1.784000e-01  2.425000e-01  9.536000e-01 -7.112070e+01]
#  [-1.002000e-01  9.686000e-01 -2.276000e-01 -8.405500e+00]
#  [-9.788000e-01 -5.500000e-02  1.971000e-01  2.382678e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012199
# Numero features senza filtering: 500
# Numero features con filtering: 106
# Frame 1314 processato. Tempo trascorso: 0:00:00.033845
#
#  [[ 1.784000e-01  2.403000e-01  9.542000e-01 -7.030180e+01]
#  [-9.910000e-02  9.692000e-01 -2.256000e-01 -8.607100e+00]
#  [-9.790000e-01 -5.430000e-02  1.967000e-01  2.384327e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012632
# Numero features senza filtering: 500
# Numero features con filtering: 98
# Frame 1315 processato. Tempo trascorso: 0:00:00.035258
#
#  [[ 1.794000e-01  2.370000e-01  9.548000e-01 -6.947380e+01]
#  [-9.820000e-02  9.700000e-01 -2.223000e-01 -8.814300e+00]
#  [-9.789000e-01 -5.390000e-02  1.973000e-01  2.386136e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.014665
# Numero features senza filtering: 500
# Numero features con filtering: 100
# Frame 1316 processato. Tempo trascorso: 0:00:00.037347
#
#  [[ 1.822000e-01  2.347000e-01  9.548000e-01 -6.862600e+01]
#  [-9.640000e-02  9.707000e-01 -2.202000e-01 -9.019100e+00]
#  [-9.785000e-01 -5.190000e-02  1.995000e-01  2.387948e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.015602
# Numero features senza filtering: 500
# Numero features con filtering: 91
# Frame 1317 processato. Tempo trascorso: 0:00:00.039444
#
#  [[ 1.862000e-01  2.323000e-01  9.547000e-01 -6.789790e+01]
#  [-9.510000e-02  9.713000e-01 -2.178000e-01 -9.228100e+00]
#  [-9.779000e-01 -5.020000e-02  2.030000e-01  2.389154e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.010976
# Numero features senza filtering: 500
# Numero features con filtering: 99
# Frame 1318 processato. Tempo trascorso: 0:00:00.032900
#
#  [[ 1.895000e-01  2.320000e-01  9.541000e-01 -6.705690e+01]
#  [-9.490000e-02  9.715000e-01 -2.173000e-01 -9.429600e+00]
#  [-9.773000e-01 -4.940000e-02  2.061000e-01  2.391023e+02]]
#
#
#
# Tempo impiegato da bm:
# 0:00:00.012677
# Numero features senza filtering: 500
# Numero features con filtering: 105
# Frame 1319 processato. Tempo trascorso: 0:00:00.036029
#
#  [[ 1.928000e-01  2.330000e-01  9.532000e-01 -6.623420e+01]
#  [-9.520000e-02  9.713000e-01 -2.181000e-01 -9.628800e+00]
#  [-9.766000e-01 -4.870000e-02  2.094000e-01  2.392795e+02]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[27], line 6, in main()
#       4 gtPoses_path="KITTI_dataset/poses/00.txt"
#       5 handler = Dataset_Handler(calib_path,images_path,gtPoses_path)
# ----> 6 trajectory= visual_odometry(handler, filter_threshold=0.5)
#
# Cell In[26], line 79, in visual_odometry(handler, stereo_matcher, detector, matcher, filter_threshold, mask, verbose, plot)
#      77         zs = trajectory[:i+2, 2, 3]
#      78         plt.plot(xs, ys, zs, c='chartreuse')
# ---> 79         plt.pause(1e-32)
#      81 if plot:
#      82     plt.close()
#
# File ~\anaconda3\envs\VO_system\lib\site-packages\matplotlib\pyplot.py:756, in pause(interval)
#     754         canvas.draw_idle()
#     755     show(block=False)
# --> 756     canvas.start_event_loop(interval)
#     757 else:
#     758     time.sleep(interval)
#
# File ~\anaconda3\envs\VO_system\lib\site-packages\matplotlib\backends\_backend_tk.py:423, in FigureCanvasTk.start_event_loop(self, timeout)
#     420     else:
#     421         self._event_loop_id = self._tkcanvas.after_idle(
#     422             self.stop_event_loop)
# --> 423 self._tkcanvas.mainloop()
#
# File ~\anaconda3\envs\VO_system\lib\tkinter\__init__.py:1429, in Misc.mainloop(self, n)
#    1427 def mainloop(self, n=0):
#    1428     """Call the mainloop of Tk."""
# -> 1429     self.tk.mainloop(n)
#
# KeyboardInterrupt:
